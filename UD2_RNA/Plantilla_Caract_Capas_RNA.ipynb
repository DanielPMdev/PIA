# %%
print("\n=== Perceptrón Multicapa (MLP) ===")
print("Número de capas (incluye entrada y salida):", mlp.n_layers_)
print("Capas ocultas:", mlp.hidden_layer_sizes)
print("Número de salidas (clases):", mlp.n_outputs_)
print("Forma de los pesos de la segunda capa:", mlp.coefs_[1].shape)
print("Bias de la segunda capa:", mlp.intercepts_[1])

# %%
# Datasets de regresión - función de error/loss y optimizador
model.compile(loss='mean_squared_error', optimizer='sgd') #adam

# Dataset de clasificación --> Función de activación = SOFTMAX
model.compile(optimizer='adam', # Optimizador
              loss='sparse_categorical_crossentropy', # Función de pérdida. y=one_hot_encoding: loss='categorical_crossentropy'
              metrics=['accuracy']) # Métrica

# %%
model.summary() #Información sobre el modelo
